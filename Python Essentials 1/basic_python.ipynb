# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("My name is Huzaifa.\nNice to meet you!")
# Out:
# My name is Huzaifa.
# Nice to meet you!

# %%
print("Programming Languages I learned:", end=" ")
print("Python, Java, C++")
# Out:
# Programming Languages I learned: Python, Java, C++

# %%
print("Python","Java", "C++", sep=" - ")
# Out:
# Python - Java - C++

# %%
print("|     |")
print("|_____|")
print("|     |")
# Out:
# |     |
# |_____|
# |     |

# %%
print("+" + 10 * "-" + "+")
print(("|" + " " * 10 + "|\n") * 5, end="")
print("+" + 10 * "-" + "+")
# Out:
# +----------+
# |          |
# |          |
# |          |
# |          |
# |          |
# +----------+

# %%
print(2+2)
# Out:
# 4

# %%
print(5-1)
# Out:
# 4

# %%
print(2*3)
# Out:
# 6

# %%
print(2/2)
# Out:
# 1.0

# %%
print(5%51)
# Out:
# 5

# %%
print(2**3)
# Out:
# 8

# %%
print(5//1)
# Out:
# 5

# %%
print((5 * ((25 % 13) + 100) / (2 * 13)) // 2)
# Out:
# 10.0
